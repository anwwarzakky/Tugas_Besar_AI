# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/dataset
# Out:
# [Errno 107] Transport endpoint is not connected: '/content/gdrive/My Drive/Colab Notebooks/dataset'
# /content

# %%
import os



train_dir = "/content/drive/My Drive/Colab Notebooks/dataset/train"
val_dir = "/content/drive/My Drive/Colab Notebooks/dataset/test"

belimbing_train_path = train_dir +'/sirih'
jeruk_train_path = train_dir +'/buaya'
belimbing_val_path = val_dir +'/sirih'
jeruk_val_path = val_dir +'/buaya'

belimbing_len_train = len(os.listdir(belimbing_train_path))
jeruk_len_train = len(os.listdir(jeruk_train_path))
belimbing_len_val = len(os.listdir(belimbing_val_path))
jeruk_len_val = len(os.listdir(jeruk_val_path))

print("jumlah dataset Training : ", belimbing_len_train + jeruk_len_train)
print("jumlah dataset validasi : ", belimbing_len_val + jeruk_len_val)
print("\n\n")
print("jumlah train kelas belimbing : ", belimbing_len_train)
print("jumlah train kelas jeruk : ", jeruk_len_train)
print("jumlah validasi kelas belimbing : ", belimbing_len_val)
print("jumlah validasi kelas jeruk : ", jeruk_len_val)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-3d74cdd304c2> in <module>
#      11 jeruk_val_path = val_dir +'/buaya'
#      12
# ---> 13 belimbing_len_train = len(os.listdir(belimbing_train_path))
#      14 jeruk_len_train = len(os.listdir(jeruk_train_path))
#      15 belimbing_len_val = len(os.listdir(belimbing_val_path))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/dataset/train/sirih'
